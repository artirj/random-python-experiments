# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
gdp=np.array([38,48,56,64,66,68,74,99,80])
gini=np.array([229,288,317,306,308,398,363,376,254])/100
colos=['r','r']
for i in range(len(gdp)-2): colos.append('b')
#for i in range(len(gdp)):plt.plot(gdp,gini,'.',color=colos[i])
sns.regplot(gdp[:2],gini[:2],color=)
sns.regplot(gdp,gini)
